# %%
import pandas as pd

# %%
df = pd.read_pickle("data/"+"training_df"+".pkl")

# %%
df = df.drop(columns="Label")

# %%
df.head()
# Out:
#                             User_ID  \
# 0  867be96f95dfc4e24541d19c6a5ab8bf
# 1  e21e132b94125e6c9401db0e53ddc316
# 2  e68c9b5d7380765a61e98b0248a2e474
# 3  1e65e06fc74c5a738f35d5a1edd6b9fc
# 4  c102ae3d3c3fb6964689a41b817be1e9
#
#                                               Tweets
# 0  Alex is too nice for love island :( RT @STVNew...
# 1  RT @AlexanderRugaev: The Crypto Finance Ecosys...
# 2  Check out these awesome cooking t-shirts &amp;...
# 3  YEWWinfo Tiny Nanoparticles to Treat a Huge Pr...
# 4  Sr. Project Manager Water / Wastewater Enginee...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4120 entries, 0 to 4119
# Data columns (total 2 columns):
# User_ID    4120 non-null object
# Tweets     4120 non-null object
# dtypes: object(2)
# memory usage: 96.6+ KB

# %%
# Testing https://towardsdatascience.com/how-i-improved-my-text-classification-model-with-feature-engineering-98fbe6c13ef3

def feature(df) :
    df['word_count'] = df['Tweets'].apply(lambda x : len(x.split()))
    df['char_count'] = df['Tweets'].apply(lambda x : len(x.replace(" ","")))
    df['word_density'] = df['word_count'] / (df['char_count'] + 1)
    df['total_length'] = df['Tweets'].apply(len)
    df['capitals'] = df['Tweets'].apply(lambda comment: sum(1 for c in comment if c.isupper()))
    df['caps_vs_length'] = df.apply(lambda row: float(row['capitals'])/float(row['total_length']),axis=1)
    df['num_exclamation_marks'] =df['Tweets'].apply(lambda x: x.count('!'))
    df['num_question_marks'] = df['Tweets'].apply(lambda x: x.count('?'))
    df['num_punctuation'] = df['Tweets'].apply(lambda x: sum(x.count(w) for w in '.,;:'))
    df['num_symbols'] = df['Tweets'].apply(lambda x: sum(x.count(w) for w in '*&$%'))
    df['num_unique_words'] = df['Tweets'].apply(lambda x: len(set(w for w in x.split())))
    df['words_vs_unique'] = df['num_unique_words'] / df['word_count']
    df["word_unique_percent"] =  df["num_unique_words"]*100/df['word_count']
    return df

# %%
feature(df)
# Out:
#                                User_ID  \
# 0     867be96f95dfc4e24541d19c6a5ab8bf
# 1     e21e132b94125e6c9401db0e53ddc316
# 2     e68c9b5d7380765a61e98b0248a2e474
# 3     1e65e06fc74c5a738f35d5a1edd6b9fc
# 4     c102ae3d3c3fb6964689a41b817be1e9
# 5     696e7ce511efdc1aa735ada20124fb84
# 6     c9f9701b0769b33adfebe73f1d8f86e9
# 7     8d72ae6b57a46b36530617556bc90fdd
# 8     a162cf99b587f3c74c8353165a6ed200
# 9     ff8c26db7278a3b51dba5e5db3f1d1ac
# 10    b280e5c3568c7aa0ee3a2914e2e4d399
# 11    580300d2455b2f5aaf7fa92459e8361b
# 12    40d7a9e308b11d2b7c587a75fea0e17d
# 13    705fdc4fb4ab17e493bd6a3bc44390db
# 14    172d6cc908b345ff8177a727903eb645
# 15    a6d56fd688c2078e01b29d2cb2376b8d
# 16    9d9a3088045b48ecddbbdc16071d6be3
# 17    49964adb1555d344ec08c82025acd559
# 18    39e32905d7a8e493e650224a16fdb99f
# 19    8e3921276e0d232333d446f3fdcb0394
# 20    75adfa6a681c7740e55adc200db0c616
# 15    #GameofThrones #ThorosofMyr: There's no story....    bot         951
# 16    the amount of pride flags he has around him, a...    bot        1325
# 17    @mike_mcgrail Pretty sure I seen your doppelga...  human        1222
# 18    Most games are lost, not won! - Casey Stengel ...    bot        1351
# 19    a person wearing a hat https://t.co/UqHgJy7ji7...    bot         816
# 20    Why the ‘Manhattan Madam’ Is Ensnared in the M...    bot        1209
# 21    Probably going to visit the folks in T.O. in t...  human        1508
# 22    I painted "Easy-going Alexander Fleming" after...    bot        2072
# 23    Check out this Big-Dog Pet Fountain - Keeps Fr...    bot        1346
# 24    Just commented on @thejournal_ie: Poll: Did yo...  human        1878
# 25    RT @jonathansteel: Speaker from @SatAppsCatapu...  human        1576
# 26    Then I ran out of our database, so we rooted y...    bot        1181
# 27    The cause of spiritual life for the spirituall...    bot         714
# 28    There's A New "Deadpool 2" Trailer And Holy He...    bot        1542
# 29    © @5sosupdateww ] https//tco/1ukhqdtduy. RT @S...    bot        1986
# ...                                                 ...    ...         ...
# 4090  RT @IainGAnderson: Glad you were able to visit...  human        1923
# 4091  Mad how birds throw on a pair of them fake gla...  human        1194
# 4092  Why isn't @Target's #grocery offering helping ...  human        1611
# 4093  All arguments have two sides, but some have no...    bot        1402
# 4094  A game where you must clear out a strange test...    bot        1451
# 4095  RT @JoParkerBear: I love that rightwingers say...  human        2346
# 4096  #goodluc….. actor... an actor. rt @xxkissmeyou...    bot        1931
# 4097  Jeffrey Tambor Is Not Returning To "Transparen...    bot        1548
# 4098  @BerthanPete @IsThisAB0t Can't see this being ...  human        2156
# 4099  @JohnRMoffitt I thought the trump base didn't ...  human        2679
# 4100  In fact I would go as far to say that it’s act...  human        1230
# 4101  Warmer Arctic temperatures are the 'new normal...    bot        1121
# 4102  On her first day back from her honeymoon, @Ste...  human        1793
# 4103  RT @TabithaKhaye: What defines us is how well ...    bot        1260
# 4104  Excited to be able to start another season. I ...  human        1446
# 4105  RT @MeredithFrost: Best thing you’ll see today...  human        1059
# 4106  RT por MAS SEGUIDORES: Da RT RT SÍGUEME\ny SIG...    bot        1747
# 4107  Senior Software Engineer Frontend – Loan Servi...    bot        3653
# 4108  I change my mind...puff-puff-give. Last candid...  human         941
# 4109  RT @Internet_SF: "Member States have failed to...  human        1990
# 4110  @Kezzang69 I can hear the Black Bull jukey cal...  human        1566
# 4111  Here's a look at the top 2018 strategic IT bud...  human        1508
# 4112  What you don't know won't hurt you but it prov...    bot        1280
# 4113  @CostaCoffee @moto Not been picked up yet! :( ...  human        1083
# 4114  New at Affiliate Marketing?  How to Start Off ...    bot        1264
# 4115  You should check this site out if you want 117...    bot        1183
# 4116  This tweet was sent via Twitter for iPhone. I ...    bot        2000
# 4117  RT @1dish4theroad: The history of #London is r...  human        2065
# 4118  12 Great Motivational Quotes here: http://t.co...    bot        1554
# 4119  I think i'm going to YOLO it. Is it going to r...  human        1521
#
#       char_count  word_density  total_length  capitals  caps_vs_length  \
# 0           5709      0.204203          6878       331        0.048124
# 1          10806      0.164893         12561      1026        0.081681
# 2           6686      0.191267          8022       629        0.078409
# 3          12954      0.140255         14771      2102        0.142306
# 4          24012      0.153250         27692      2364        0.085368
# 5           5418      0.186566          6423       347        0.054025
# 6           4642      0.180918          5481       374        0.068236
# 7           5445      0.204554          6559       456        0.069523
# 8           6793      0.215484          8258       404        0.048922
# 9          10610      0.147677         12185       902        0.074025
# 10          2833      0.070572          3033       401        0.132212
# 11          5844      0.134132          6598       739        0.112004
# 12          7156      0.180243          8449       474        0.056101
# 13         10917      0.174940         12807       938        0.073241
# 14          7923      0.185386          9420       737        0.078238
# 15         12864      0.073921         13825      2267        0.163978
# 16          7568      0.175056          8875      1126        0.126873
# 17          6618      0.184620          7822       633        0.080926
# 18          6820      0.198065          8214       649        0.079011
# 19          4879      0.167213          5695       411        0.072169
# 20         10065      0.120107         11274      1738        0.154160
# 21          8411      0.179268          9987       845        0.084610
# 22         15088      0.137319         17139      1202        0.070132
# 23          6885      0.195469          8276       627        0.075761
# 24         11321      0.165872         13207       773        0.058530
# 25         10917      0.144349         12498       897        0.071771
# 26          5413      0.218138          6594       270        0.040946
# 27          5042      0.141582          5756       566        0.098332
# 28         10723      0.143790         12265      2122        0.173013
# 29         11358      0.174839         13314      1855        0.139327
# ...          ...           ...           ...       ...             ...
# 4090       11657      0.164951         13579      1101        0.081081
# 4091        6442      0.185317          7636       438        0.057360
# 4092       10020      0.160762         11635       776        0.066695
# 4093        6977      0.200917          8429       652        0.077352
# 4094        6638      0.218557          8089       132        0.016318
# 4095       11885      0.197375         14218       795        0.055915
# 4096       11026      0.175116         12947      1494        0.115394
# 4097       10814      0.143135         12361      1904        0.154033
# 4098       11373      0.189555         13512       861        0.063721
# 4099       13795      0.194187         16457      1199        0.072857
# 4100        6357      0.193457          7584       527        0.069488
# 4101        9533      0.117579         10654      1168        0.109630
# 4102       10121      0.177139         11911      1070        0.089833
# 4103        6400      0.196844          7655       427        0.055781
# 4104        8397      0.172184          9849       711        0.072190
# 4105        5697      0.185855          6758       520        0.076946
# 4106       11466      0.152350         13017      3539        0.271875
# 4107       25659      0.142362         29326      2927        0.099809
# 4108        6485      0.145082          7470       769        0.102945
# 4109       11444      0.173875         13431       878        0.065371
# 4110        8977      0.174426         10540       854        0.081025
# 4111       11044      0.136532         12554      1515        0.120679
# 4112        6829      0.187408          8169       678        0.082997
# 4113        6511      0.166308          7593       822        0.108258
# 4114        7328      0.172466          8593      1205        0.140230
# 4115        5924      0.199662          7111       221        0.031079
# 4116       10404      0.192215         12404       924        0.074492
# 4117       11535      0.179005         13568       840        0.061910
# 4118        7614      0.204071          9166       543        0.059241
# 4119        7861      0.193462          9389       718        0.076472
#
#       num_exclamation_marks  num_question_marks  num_punctuation  num_symbols  \
# 0                        28                   9              100            5
# 1                        17                   9              322           21
# 2                        20                   6              193            8
# 3                         8                  12              576            2
# 4                         2                   5              828          111
# 5                        31                  12               81            4
# 6                        10                  10              102            2
# 7                        14                  11              183            9
# 8                        18                  15              102            3
# 9                         8                   7              279            7
# 10                        0                   0              200            0
# 11                        6                   1              267            4
# 12                        9                   7              223           14
# 13                       25                  17              303           11
# 14                        4                  19              219            6
# 15                       21                   0              696            0
# 16                        7                  11              294            5
# 17                       12                  19              171            2
# 18                       18                   9              204            5
# 19                        0                   0              202            0
# 20                        0                   4              503            0
# 21                        8                   8              323           12
# 22                       18                   8              277            3
# 23                       14                   5              212            8
# 24                        5                  21              328            4
# 25                       19                   6              275           25
# 26                        0                  14              133            5
# 27                        6                  16              255            0
# 28                        0                   9              431            5
# 29                      123                   9              320           36
# ...                     ...                 ...              ...          ...
# 4090                     44                   8              395           39
# 4091                      0                   7               91            0
# 4092                      2                  21              299           24
# 4093                     13                  10              197            9
# 4094                      0                   0                8            0
# 4095                     21                  18              255           10
# 4096                     85                  10              325           34
# 4097                      0                   8              407            2
# 4098                     11                  20              296            5
# 4099                     18                  36              339           14
# 4100                      2                   1              181            0
# 4101                      1                   3              462            2
# 4102                     12                  10              349            4
# 4103                      7                   3              246           10
# 4104                     17                   7              252            3
# 4105                      6                   6              110            4
# 4106                     69                   6               76           14
# 4107                      0                  16              955           51
# 4108                     18                  16              390           15
# 4109                      3                   9              283            7
# 4110                      5                   5              324            7
# 4111                      5                  10              339            6
# 4112                     18                   8              208            7
# 4113                     48                   6              195            5
# 4114                      3                  11              245            2
# 4115                     21                   0              275            1
# 4116                      0                   0              400          100
# 4117                     77                   7              345            5
# 4118                      0                   3              255            7
# 4119                     36                  15              267            3
#
#       num_unique_words  words_vs_unique  word_unique_percent
# 0                  657         0.563465            56.346484
# 1                 1119         0.627946            62.794613
# 2                  732         0.572322            57.232213
# 3                  960         0.528343            52.834342
# 4                 1932         0.525000            52.500000
# 5                  608         0.601385            60.138477
# 6                  514         0.611905            61.190476
# 7                  769         0.690305            69.030521
# 8                  712         0.486339            48.633880
# 9                  552         0.352265            35.226548
# 10                 109         0.545000            54.500000
# 11                 489         0.623724            62.372449
# 12                 742         0.575194            57.519380
# 13                1044         0.546597            54.659686
# 14                 896         0.609939            60.993873
# 15                 474         0.498423            49.842271
# 16                 793         0.598491            59.849057
# 17                 753         0.616203            61.620295
# 18                 805         0.595855            59.585492
# 19                 260         0.318627            31.862745
# 20                 775         0.641026            64.102564
# 21                 944         0.625995            62.599469
# 22                 879         0.424228            42.422780
# 23                 768         0.570579            57.057949
# 24                1043         0.555378            55.537806
# 25                 894         0.567259            56.725888
# 26                 667         0.564776            56.477561
# 27                 283         0.396359            39.635854
# 28                 886         0.574578            57.457847
# 29                 940         0.473313            47.331319
# ...                ...              ...                  ...
# 4090              1085         0.564223            56.422257
# 4091               605         0.506700            50.670017
# 4092               927         0.575419            57.541899
# 4093               745         0.531384            53.138374
# 4094               535         0.368711            36.871123
# 4095              1264         0.538789            53.878943
# 4096               952         0.493009            49.300880
# 4097               988         0.638243            63.824289
# 4098              1158         0.537106            53.710575
# 4099              1380         0.515118            51.511758
# 4100               704         0.572358            57.235772
# 4101               840         0.749331            74.933095
# 4102              1129         0.629671            62.967094
# 4103               642         0.509524            50.952381
# 4104               845         0.584371            58.437068
# 4105               663         0.626062            62.606232
# 4106               157         0.089868             8.986835
# 4107              1662         0.454969            45.496852
# 4108               663         0.704570            70.456961
# 4109              1164         0.584925            58.492462
# 4110               978         0.624521            62.452107
# 4111               761         0.504642            50.464191
# 4112               769         0.600781            60.078125
# 4113               725         0.669437            66.943675
# 4114               600         0.474684            47.468354
# 4115               307         0.259510            25.950972
ahahahahahah 😭 “but how big is big” @_amylennie Skittle nips @_amylennie U got this x @_amylennie Love ya ❣️ worst cunt anyway @laurenfarquhar_ @jennyhastie @karmen1998 @beckyfrancesxo @erinwallx @jennyhastie @axmcx @jennyhastie @jennyhastie @Jamienelder1 Pedo Fuming it’s far too hot to sleep : ( RT @hopemumbi: Hope Laura rattles Megan’s cunt right across the flare and THEN she’ll see Oh ya fucker Megan’s now laughing 😭 drag her Laura hun RT @Dakota_DK: #WhatTheFluffChallenge https://t.co/9hZrGARzBZ @_amylennie Get booked mags @_amylennie Just love u ❣️❣️ #NewProfiIePic https://t.co/xsjPcbvKBw @_amylennie Drop them then @_amylennie Cheeky Nearly cried in work lost my  ...

# %%
df.head()
# Out:
#                             User_ID  \
# 0  867be96f95dfc4e24541d19c6a5ab8bf
# 1  e21e132b94125e6c9401db0e53ddc316
# 2  e68c9b5d7380765a61e98b0248a2e474
# 3  1e65e06fc74c5a738f35d5a1edd6b9fc
# 4  c102ae3d3c3fb6964689a41b817be1e9
#
#                                               Tweets
# 0  Alex is too nice for love island :( RT @STVNew...
# 1  RT @AlexanderRugaev: The Crypto Finance Ecosys...
# 2  Check out these awesome cooking t-shirts &amp;...
# 3  YEWWinfo Tiny Nanoparticles to Treat a Huge Pr...
# 4  Sr. Project Manager Water / Wastewater Enginee...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english', min_df = 0.01)

# %%
X = tfidf.fit_transform(df['Tweets'])

# %%
feature_names = tfidf.get_feature_names()

# %%
# https://stackoverflow.com/questions/43577590/adding-sparse-matrix-from-countvectorizer-into-dataframe-with-complimentary-info
for i, col in enumerate(tfidf.get_feature_names()):
    df[col] = pd.SparseSeries(X[:, i].toarray().ravel(), fill_value=0)

# %%
df.head()
# Out:
#                             User_ID  \
# 0  867be96f95dfc4e24541d19c6a5ab8bf
# 1  e21e132b94125e6c9401db0e53ddc316
# 2  e68c9b5d7380765a61e98b0248a2e474
# 3  1e65e06fc74c5a738f35d5a1edd6b9fc
# 4  c102ae3d3c3fb6964689a41b817be1e9
#
#                                               Tweets   00       000   01   02  \
# 0  Alex is too nice for love island :( RT @STVNew...  0.0  0.000000  0.0  0.0
# 1  RT @AlexanderRugaev: The Crypto Finance Ecosys...  0.0  0.013308  0.0  0.0
# 2  Check out these awesome cooking t-shirts &amp;...  0.0  0.000000  0.0  0.0
# 3  YEWWinfo Tiny Nanoparticles to Treat a Huge Pr...  0.0  0.000000  0.0  0.0
# 4  Sr. Project Manager Water / Wastewater Enginee...  0.0  0.006329  0.0  0.0
#
#     03   04        05   06     ...       zealand  zeppelin  zero       zig  \
# 0  0.0  0.0  0.000000  0.0     ...      0.000000       0.0   0.0  0.000000
# 1  0.0  0.0  0.000000  0.0     ...      0.000000       0.0   0.0  0.000000
# 2  0.0  0.0  0.000000  0.0     ...      0.000000       0.0   0.0  0.035924
# 3  0.0  0.0  0.000000  0.0     ...      0.016835       0.0   0.0  0.000000
# 4  0.0  0.0  0.011401  0.0     ...      0.025959       0.0   0.0  0.000000
#
#     ziglar       zip  zombie      zone  zoo  zuckerberg
# 0  0.00000  0.000000     0.0  0.000000  0.0         0.0
# 1  0.00000  0.000000     0.0  0.000000  0.0         0.0
# 2  0.03653  0.000000     0.0  0.000000  0.0         0.0
# 3  0.00000  0.000000     0.0  0.000000  0.0         0.0
# 4  0.00000  0.012874     0.0  0.010142  0.0         0.0
#
# [5 rows x 7984 columns]

# %%
df.to_pickle("data/"+"'training_df_with_basic_features'"+".pkl")

# %%
df = feature(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d509bf04ea7a> in <module>()
# ----> 1 df = feature(df)
#
# NameError: name 'feature' is not defined

# %%
df.head()
# Out:
#                             User_ID  \
# 0  867be96f95dfc4e24541d19c6a5ab8bf
# 1  e21e132b94125e6c9401db0e53ddc316
# 2  e68c9b5d7380765a61e98b0248a2e474
# 3  1e65e06fc74c5a738f35d5a1edd6b9fc
# 4  c102ae3d3c3fb6964689a41b817be1e9
#
#                                               Tweets   00       000   01   02  \
# 0  Alex is too nice for love island :( RT @STVNew...  0.0  0.000000  0.0  0.0
# 1  RT @AlexanderRugaev: The Crypto Finance Ecosys...  0.0  0.013308  0.0  0.0
# 2  Check out these awesome cooking t-shirts &amp;...  0.0  0.000000  0.0  0.0
# 3  YEWWinfo Tiny Nanoparticles to Treat a Huge Pr...  0.0  0.000000  0.0  0.0
# 4  Sr. Project Manager Water / Wastewater Enginee...  0.0  0.006329  0.0  0.0
#
#     03   04        05   06         ...           total_length  capitals  \
# 0  0.0  0.0  0.000000  0.0         ...                   6878       331
# 1  0.0  0.0  0.000000  0.0         ...                  12561      1026
# 2  0.0  0.0  0.000000  0.0         ...                   8022       629
# 3  0.0  0.0  0.000000  0.0         ...                  14771      2102
# 4  0.0  0.0  0.011401  0.0         ...                  27692      2364
#
#    caps_vs_length  num_exclamation_marks  num_question_marks  num_punctuation  \
# 0        0.048124                     28                   9              100
# 1        0.081681                     17                   9              322
# 2        0.078409                     20                   6              193
# 3        0.142306                      8                  12              576
# 4        0.085368                      2                   5              828
#
#    num_symbols  num_unique_words  words_vs_unique  word_unique_percent
# 0            5               657         0.563465            56.346484
# 1           21              1119         0.627946            62.794613
# 2            8               732         0.572322            57.232213
# 3            2               960         0.528343            52.834342
# 4          111              1932         0.525000            52.500000
#
# [5 rows x 7997 columns]

# %%
df = pd.read_pickle("data/"+"training_df_with_basic_features"+".pkl")

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['Label']
X = df.drop(columns=['Label', 'User_ID', 'Tweets'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.50, random_state=42)

# %%
X_train.columns
# Out:
# Index(['00', '000', '01', '02', '03', '04', '05', '06', '07', '08',
#        ...
#        'total_length', 'capitals', 'caps_vs_length', 'num_exclamation_marks',
#        'num_question_marks', 'num_punctuation', 'num_symbols',
#        'num_unique_words', 'words_vs_unique', 'word_unique_percent'],
#       dtype='object', length=7995)

# %%
clf = make_pipeline(StandardScaler(), SVC())

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('svc', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
from sklearn.metrics import accuracy_score

# %%
predicted = clf.predict(X_test)

# %%
acc = accuracy_score(predicted, y_test)

# %%
print(acc)
# Out:
# 0.9470873786407767
